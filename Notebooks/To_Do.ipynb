# %% [markdown]
# SCHEMA TODO
# - Create Log Id for time stamp tables,
# -

# %% [markdown]
# -Figure out how to format the date on each df
# -Function to clean
# -figure out what to keep
# -Redo ERD
# -create database
# -Add custom tables
# -everything else
# -create requirements.txt
# -start using a venv
# -remove commented code out, unnecesary comments

# %% [markdown]
# THINGS I LEARNED
# -treemap and sunburst problems with null and negatives
# -venv if I launch from a different dir
# -figure out how to deal with github size
# -date time function errors
# -function typo error
# -deal with extremes influence

# %% [markdown]
# STRETCH GOALS
# validate schema for build functions

# %% [markdown]
# is it okay to remove logs where intensity is 0
